# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/Fianl_Engg_Cuttoff.xlsx')

# %%
df['Branch Name'] = df['Branch Name'].str.replace('\n', ' ')

# %%
df.head()
# Out:
#                   Branch Name     1G  1K     1R    2AG    2AK    2AR    2BG  \
# 0  AI Artificial Intelligence   7418  --     --   6685     --  10689   8120
# 1                    CE Civil  66271  --  66811  68461  71770  77151  76027
# 2                CS Computers   2910  --     --   3181     --   5152   3894
# 3              EC Electronics   7832  --  13558  10560  13617  11587  11675
# 4               EE Electrical  28948  --     --  21923  29444  27371  22746
#
#      2BK     2BR  ...     GM    GMK    GMR    SCG    SCK    SCR    STG STK  \
# 0  38720      --  ...   4202  10372   6261  19929     --  22965  12296  --
# 1     --  130565  ...  46143  57164  54344  71349  82281  76048  61725  --
# 2     --      --  ...   1969   3799   2668   9515     --  14016   7407  --
# 3     --   26769  ...   6666  12431   9232  26317  29003  34685  17016  --
# 4     --      --  ...  15937  23575  22057  45856  50666  56019  32172  --
#
# ...

# %%
df_GM = df[["Branch Name", "GM" , "College Code and Name"]]

# %%
df_GM
# Out:
#                     Branch Name      GM  \
# 0    AI Artificial Intelligence    4202
# 1                      CE Civil   46143
# 2                  CS Computers    1969
# 3                EC Electronics    6666
# 4                 EE Electrical   15937
# ..                          ...     ...
# 316             IE Info.Science   15836
# 317               ME Mechanical  100891
# 318             MT Mechatronics   65179
# 319         RO Auto. And Robot.   37978
# 320       SS CS and System Engg   23512
#
#                                  College Code and Name
# 0    E001  University of Visvesvaraya College of En...
# 1    E001  University of Visvesvaraya College of En...
# 2    E001  University of Visvesvaraya College of En...
# 3    E001  University of Visvesvaraya College of En...
# 4    E001  University of Visvesvaraya College of En...
# ..                                                 ...
# 316                   E232  Reva University  Bangalore
# ...

# %%
df_GM[df_GM["Branch Name"] == "CS Computers"]
# Out:
# Branch Name              36
# GM                       36
# College Code and Name    36
# dtype: int64

# %%
df_GM['Caste'] = 'GM'
# Out:
# <ipython-input-21-d17d9b49e5ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GM['Caste'] = 'GM'

# %%
df.drop(columns = "Caste")
# Out:
#                     Branch Name      1G  1K     1R     2AG    2AK     2AR  \
# 0    AI Artificial Intelligence    7418  --     --    6685     --   10689
# 1                      CE Civil   66271  --  66811   68461  71770   77151
# 2                  CS Computers    2910  --     --    3181     --    5152
# 3                EC Electronics    7832  --  13558   10560  13617   11587
# 4                 EE Electrical   28948  --     --   21923  29444   27371
# ..                          ...     ...  ..    ...     ...    ...     ...
# 316             IE Info.Science   18873  --     --   17635     --   19521
# 317               ME Mechanical  111875  --     --  127727     --  167491
# 318             MT Mechatronics   68279  --     --  101037     --      --
# 319         RO Auto. And Robot.   46324  --     --   48790     --  103602
# 320       SS CS and System Engg   29080  --     --   32770     --   45390
#
#         2BG    2BK     2BR  ...      GM     GMK     GMR     SCG    SCK    SCR  \
# ...

# %%
df_GM.rename(columns = {'GM':'Rank'}, inplace = "True")
# Out:
# <ipython-input-27-1f4a6c5f17f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GM.rename(columns = {'GM':'Rank'}, inplace = "True")

# %%
df_GM_CS = df_GM[df_GM['Branch Name'] == 'CS Computers' ]
df_GM_CS
# Out:
#       Branch Name   Rank                              College Code and Name  \
# 2    CS Computers   1969  E001  University of Visvesvaraya College of En...
# 8    CS Computers  10946  E002  S K S J T Institute of Engineering.  Ban...
# 18   CS Computers   7278  E004  Dr. Ambedkar Institute Of Technology  Ba...
# 29   CS Computers    158      E005  R. V. College of Engineering  Bangalore
# 46   CS Computers    827  E006  M S Ramaiah Institute of Technology  Ban...
# 64   CS Computers   3100  E007  Dayananda Sagar College of Engineering  ...
# 79   CS Computers    841  E048  B M S College of Engineering  Basavanagu...
# 92   CS Computers  10815  E060  Dr. Ambedkar Institute Of Technology  Jn...
# 98   CS Computers  24522  E078  The Oxford College of Engineering  Banga...
# 108  CS Computers  14749   E079  Acharya Institute of Technology  Bangalore
# 123  CS Computers  39398    E083  H.K.B.K.College of Engineering  Bangalore
# ...

# %%
df_GM_CS = df_GM_CS.sort_values('Rank')

# %%
plt.plot(df_GM_CS["College Code and Name"], df_GM_CS["Rank"])
plt.show()

# %%
df_GM_CS = df_GM_CS.reset_index()

# %%
df_GM_CS
# Out:
#     level_0  index   Branch Name   Rank  \
# 0         3     29  CS Computers    158
# 1         4     46  CS Computers    827
# 2         6     79  CS Computers    841
# 3         0      2  CS Computers   1969
# 4         5     64  CS Computers   3100
# 5        32    282  CS Computers   4191
# 6        29    257  CS Computers   6702
# 7        21    194  CS Computers   6932
# 8        31    273  CS Computers   6979
# 9         2     18  CS Computers   7278
# 10       26    235  CS Computers   7448
# 11       19    180  CS Computers  10280
# 12        7     92  CS Computers  10815
# 13        1      8  CS Computers  10946
# 14       35    311  CS Computers  12510
# 15       34    300  CS Computers  13450
# 16       30    264  CS Computers  14602
# 17        9    108  CS Computers  14749
# 18       24    220  CS Computers  17211
# 19       27    242  CS Computers  20597
# 20       20    186  CS Computers  23976
# 21       15    149  CS Computers  24364
# ...

# %%
df_GM_CS = df_GM_CS.drop(columns = "index")

# %%
df_GM_CS
# Out:
#      Branch Name   Rank                              College Code and Name  \
# 0   CS Computers    158      E005  R. V. College of Engineering  Bangalore
# 1   CS Computers    827  E006  M S Ramaiah Institute of Technology  Ban...
# 2   CS Computers    841  E048  B M S College of Engineering  Basavanagu...
# 3   CS Computers   1969  E001  University of Visvesvaraya College of En...
# 4   CS Computers   3100  E007  Dayananda Sagar College of Engineering  ...
# 5   CS Computers   4191  E126  B M S Institute of Technology and Manage...
# 6   CS Computers   6702  E105  Nitte Meenakshi Institutute of Technolog...
# 7   CS Computers   6932  E099  New Horizon College of Engineering  Bang...
# 8   CS Computers   6979       E118  RNS Institute of Technology  Bangalore
# 9   CS Computers   7278  E004  Dr. Ambedkar Institute Of Technology  Ba...
# 10  CS Computers   7448     E107  B N M Institute of Technology  Bangalore
# ...

# %%
df_2AG = df[["Branch Name", "2AG" , "College Code and Name"]]
df_2AG.rename(columns = {'2AG':'Rank'}, inplace = "True")
df_2AG['Caste'] = '2AG'
df_2AG
# Out:
# <ipython-input-53-035d2c9b1b32>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2AG.rename(columns = {'2AG':'Rank'}, inplace = "True")
# <ipython-input-53-035d2c9b1b32>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2AG['Caste'] = '2AG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence    6685
# 1                      CE Civil   68461
# 2                  CS Computers    3181
# 3                EC Electronics   10560
# 4                 EE Electrical   21923
# ..                          ...     ...
# ...

# %%
df_2BG = df[["Branch Name", "2BG" , "College Code and Name"]]
df_2BG.rename(columns = {'2BG':'Rank'}, inplace = "True")
df_2BG['Caste'] = '2BG'
df_2BG
# Out:
# <ipython-input-54-967b7948623b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2BG.rename(columns = {'2BG':'Rank'}, inplace = "True")
# <ipython-input-54-967b7948623b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2BG['Caste'] = '2BG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence    8120
# 1                      CE Civil   76027
# 2                  CS Computers    3894
# 3                EC Electronics   11675
# 4                 EE Electrical   22746
# ..                          ...     ...
# ...

# %%
df_3AG = df[["Branch Name", "3AG" , "College Code and Name"]]
df_3AG.rename(columns = {'3AG':'Rank'}, inplace = "True")
df_3AG['Caste'] = '3AG'
df_3AG
# Out:
# <ipython-input-55-8e10cc49b393>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3AG.rename(columns = {'3AG':'Rank'}, inplace = "True")
# <ipython-input-55-8e10cc49b393>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3AG['Caste'] = '3AG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence    5128
# 1                      CE Civil   56151
# 2                  CS Computers    2137
# 3                EC Electronics    8420
# 4                 EE Electrical   16624
# ..                          ...     ...
# ...

# %%
df_3BG = df[["Branch Name", "3BG" , "College Code and Name"]]
df_3BG.rename(columns = {'3BG':'Rank'}, inplace = "True")
df_3BG['Caste'] = '3BG'
df_3BG
# Out:
# <ipython-input-56-0137e8bb7cd4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3BG.rename(columns = {'3BG':'Rank'}, inplace = "True")
# <ipython-input-56-0137e8bb7cd4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3BG['Caste'] = '3BG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence    4822
# 1                      CE Civil   58789
# 2                  CS Computers    2262
# 3                EC Electronics    7112
# 4                 EE Electrical   22470
# ..                          ...     ...
# ...

# %%
df_GM = df[["Branch Name", "GM" , "College Code and Name"]]
df_GM.rename(columns = {'GM':'Rank'}, inplace = "True")
df_GM['Caste'] = 'GM'
df_GM
# Out:
# <ipython-input-58-d4f4134dac12>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GM.rename(columns = {'GM':'Rank'}, inplace = "True")
# <ipython-input-58-d4f4134dac12>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_GM['Caste'] = 'GM'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence    4202
# 1                      CE Civil   46143
# 2                  CS Computers    1969
# 3                EC Electronics    6666
# 4                 EE Electrical   15937
# ..                          ...     ...
# ...

# %%
df_SCG = df[["Branch Name", "SCG" , "College Code and Name"]]
df_SCG.rename(columns = {'SCG':'Rank'}, inplace = "True")
df_SCG['Caste'] = 'SCG'
df_SCG
# Out:
# <ipython-input-59-ca505a56b9e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_SCG.rename(columns = {'SCG':'Rank'}, inplace = "True")
# <ipython-input-59-ca505a56b9e1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_SCG['Caste'] = 'SCG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence   19929
# 1                      CE Civil   71349
# 2                  CS Computers    9515
# 3                EC Electronics   26317
# 4                 EE Electrical   45856
# ..                          ...     ...
# ...

# %%
df_STG = df[["Branch Name", "STG" , "College Code and Name"]]
df_STG.rename(columns = {'STG':'Rank'}, inplace = "True")
df_STG['Caste'] = 'STG'
df_STG
# Out:
# <ipython-input-60-b25c4b14311e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_STG.rename(columns = {'STG':'Rank'}, inplace = "True")
# <ipython-input-60-b25c4b14311e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_STG['Caste'] = 'STG'
#                     Branch Name    Rank  \
# 0    AI Artificial Intelligence   12296
# 1                      CE Civil   61725
# 2                  CS Computers    7407
# 3                EC Electronics   17016
# 4                 EE Electrical   32172
# ..                          ...     ...
# ...

# %%
combined_df = pd.concat([df_STG,df_SCG, df_GM, df_2AG, df_2BG, df_3AG, df_3BG])

# %%
combined_df[combined_df['Rank'] == '--']
# Out:
# Empty DataFrame
# Columns: [Branch Name, Rank, College Code and Name, Caste]
# Index: []

# %%
combined_df = combined_df[combined_df['Rank'] != "--"]

# %%
combined_df = combined_df[["Branch Name" , "Rank", "Caste", "College Code and Name"]]

# %%
combined_df
# Out:
#                     Branch Name    Rank Caste  \
# 0    AI Artificial Intelligence   12296   STG
# 1                      CE Civil   61725   STG
# 2                  CS Computers    7407   STG
# 3                EC Electronics   17016   STG
# 4                 EE Electrical   32172   STG
# ..                          ...     ...   ...
# 316             IE Info.Science   15938   3BG
# 317               ME Mechanical  114036   3BG
# 318             MT Mechatronics   66850   3BG
# 319         RO Auto. And Robot.   38010   3BG
# 320       SS CS and System Engg   26866   3BG
#
#                                  College Code and Name
# 0    E001  University of Visvesvaraya College of En...
# 1    E001  University of Visvesvaraya College of En...
# 2    E001  University of Visvesvaraya College of En...
# 3    E001  University of Visvesvaraya College of En...
# 4    E001  University of Visvesvaraya College of En...
# ..                                                 ...
# ...

# %%
final_data = combined_df

# %%
X = final_data.iloc[:, :-1].values
y = final_data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
#combined_df.to_excel("/content/output.xlsx")

# %%
#combined_df = combined_df.dropna()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1c5dfa628fd6> in <cell line: 3>()
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 regressor = DecisionTreeRegressor(random_state = 0)
# ----> 3 regressor.fit(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X,
#    1249             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
#     187                 X, y, validate_separately=(check_X_params, check_y_params)
# ...
